# %% [markdown]
# # Markdown Usage Demonstration
#
# This notebook demonstrates proper use of Markdown for structuring and documenting a Jupyter Notebook.
#
# ## Objectives
#
# - Use headings to organize content
# - Use lists for clarity
# - Demonstrate inline code and code blocks
# - Maintain readability and structure

# %% [markdown]
# ## Key Concepts
#
# The following concepts are demonstrated in this notebook:
#
# - Markdown headings for structure
# - Unordered lists for grouping ideas
# - Ordered lists for step-by-step explanation
# - Inline code formatting
# - Code blocks inside Markdown

# %% [markdown]
# ## Steps for Execution
#
# 1. Define a variable using `a = 10`
# 2. Perform a simple calculation
# 3. Print the result using `print()`
#
# Inline code like `a = 10` helps highlight important parts of the explanation.

# %%
a = 10
b = a + 5
print("Result:", b)

# %% [markdown]
# ## Example Code Block
#
# Below is a sample Python code block written inside Markdown:
#
# ```python
# x = 5
# y = x * 2
# print(y)

# %% [markdown]
# ## Explanation
#
# The code above performs a simple arithmetic operation. The Markdown cells before and after code help in explaining what the code does and improve readability.
#
# This structure ensures that the notebook is easy to understand for others.
