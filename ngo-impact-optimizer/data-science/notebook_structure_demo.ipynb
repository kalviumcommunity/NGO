# %%
# Notebook Structure Demonstration

This notebook demonstrates correct usage of Markdown and Code cells in Jupyter Notebook. The focus is on maintaining clarity, structure, and separation between explanation and execution.
# Out:
#   Cell In[3], line 3
#     This notebook demonstrates correct usage of Markdown and Code cells in Jupyter Notebook. The focus is on maintaining clarity, structure, and separation between explanation and execution.
#          ^
# SyntaxError: invalid syntax

# %%
## Step 1: Basic Python Output

In this step, we execute a simple Python command to print a message. This demonstrates how code execution works in a structured notebook environment.

# %%
print("Hello, this is a structured notebook")
# Out:
# Hello, this is a structured notebook

# %%
## Step 2: Simple Calculation

In this step, we perform a basic arithmetic operation to show how computations are executed within a code cell.

# %%
result = 10 + 5
print("The result is:", result)
# Out:
# The result is: 15
